# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Performance of maxN for Different Search Depths
#
# The execution time of the maxN algorithm largely depends on the given search depth (how many turns the algorithm is allowed to look into all possible futures). However, even for the same search depth execution time differs quite strongly. Therefore, it is the purpose of this script, to find out, which parameters cause the execution time to go up.

# %% [markdown]
# ## Prerequisite
#
# This script uses randomly generated games to measure performance. These random games were geneated by the node-script in `src/data-generation/random-games.ts`. The result is stored to two files:
#
# - `data/random-games.json` which contains the game states for all games and moves (thus the complete game courses)
# - `data/random-games.csv` which contains some analytical data to every move made in the random games (like number of players, number of pawns etc.)
#
# Let's have a look at the analytical data:

# %%
games_data = pd.read_csv('../data/random-games.csv')
games_data.head(3)
# Out:
#    turn  playerOnTurn  boardSize  numOfPlayers  numOfPawns  numOfPawnsRed  \
# 0     1             0         64             2           8              4
# 1     2             2         56             2           8              4
# 2     3             0         48             2           8              4
#
#    numOfPawnsGreen  numOfPawnsYellow  numOfPawnsBlue  maxNumOfPawns  \
# 0                0                 4               0              4
# 1                0                 4               0              4
# 2                0                 4               0              4
#
#    numOfMovesCurrent  numOfMovesRed  numOfMovesGreen  numOfMovesYellow  \
# 0                 13             13                0                13
# 1                 13             26                0                13
# 2                 24             24                0                20
#
#    numOfMovesBlue  numOfMovesAll
# 0               0             26
# 1               0             39
# 2               0             44

# %% [markdown]
# ## Measuring Performance
#
# To measure the performance for each turn, another script was used. The script can be found at `src/data-generation/max-n-performance.ts`. It measured the execution time in milliseconds for every move from the random games. It did so with a search depth of 1, 2, 3 and 4 (4 already took a very long time to execute).
#
# The results were stored to `data/max-n-performance.csv`. Let's have look:

# %%
games_perf = pd.read_csv('../data/max-n-performance.csv')
games_perf
# Out:
#      depth1  depth2  depth3  depth4
# 0         2       5      45     462
# 1         2       7      73     642
# 2         2      11     119    1151
# 3         2      12     115    1065
# 4         1      10     138     977
# ..      ...     ...     ...     ...
# 964       0       0       0       0
# 965       0       0       0       0
# 966       0       0       0       0
# 967       0       0       0       0
# 968       0       0       0       0
#
# [969 rows x 4 columns]

# %% [markdown]
# ## Finding the Attribute with the Highest Correlation
#
# Now, we try to find out if any one of the analytics (number of players, number of pawns, etc.) has a high effect on the execution time.
#
# We will use a linear regression model with $x =$ each of our attributes and $y =$ each of the different search depths. We calculate the coefficient of determination ($R^2$) between an attribute and the execution time.
#
# Let's see if some attributes have a stronger correlation to the execution time than others.

# %%
def calcRsquared(x, y):
    corr_matrix = np.corrcoef(x, y)
    return corr_matrix[0,1] ** 2

def calcRsquaredAsDf():
    index = []
    columns = []

    table = []

    for keyData, valueData in games_data.iteritems():
        index.append(keyData)
        table.append([])
        i = len(table) - 1
        for keyPerf, valuePerf in games_perf.iteritems():
            rSquared = calcRsquared(valueData, valuePerf)
            table[i].append(rSquared)

    for keyPerf, valuePerf in games_perf.iteritems(): 
        columns.append(keyPerf)
        
    return pd.DataFrame(table,index,columns)
        
# `style` only works in live preview and has to be deactivated when exporting as pdf
calcRsquaredAsDf().style.background_gradient(axis=0,vmin=0.2)
# Out:
# <style  type="text/css" >
#     #T_34136044_83cc_11ea_92a7_0242ac120002row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row2_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row2_col1 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row2_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row2_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row4_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row4_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row4_col3 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row7_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row8_col2 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row9_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row9_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row9_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row10_col1 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row10_col2 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row10_col3 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row12_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row12_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row12_col2 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row12_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row13_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row13_col1 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row13_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row13_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row14_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row14_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row14_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_34136044_83cc_11ea_92a7_0242ac120002row14_col3 {
#             background-color:  #a4bcda;

# %% [markdown]
# ## Intermediate Results
#
# The attribute with the highest correlation is the number of moves. This is quite logical as the number of moves is also equivalant to the branching factor.
#
# Some other factors have an effect as well (number of pawns and board size). However, if we think about it, they support our hypothesis even more. The more pawns there are and the bigger the board is, the more moves can be made by the pawns. So, the number of moves remains the most important factor.
#
# Different ways of counting the number of moves were used. There is the number of moves of the current player (who is currently on turn), the number of moves for each of the players (regardless whether they are on turn or not) and the sum of all possible moves of players.
#
# For a search depth of 1, the number of moves of the current player is most significant (which makes sense because a depth of 1 means, we are only considering the currently possible moves). As soon as we start looking further into the future, the sum of all possible moves of all players is the most significant factor. This also makes sense as we have to compute all possible moves of the respective player for future moves as well.
#
# **_Conclusion_: We should determine the allowed search depth for the maxN algorithm by the number of moves *all* pawns on the board can make, regardless if the corresponding player is currently on turn or not.**
#
# We continue in the next document: [max-n-depth.pdf](./max-n-depth.pdf)
